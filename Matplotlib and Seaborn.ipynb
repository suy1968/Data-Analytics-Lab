# %% [markdown]
# # Import the library

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Loading the dataset

# %%
a = pd.read_csv(r'C:\Users\Admin\Desktop\flight_details.csv')

# %%
a.describe()
# Out:
#              Years  Passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
a.shape
# Out:
# (144, 3)

# %%
a.sample(5)
# Out:
#      Years    Months  Passengers
# 66    1954      July         302
# 114   1958      July         491
# 91    1956    August         405
# 117   1958   October         359
# 82    1955  November         237

# %%
sns.relplot(x="Passengers", y="Months", data=a)  #the points are plotted in two dimensions, another 
#dimension can be added to the plot by coloring the points according to a third variable

# %%
sns.relplot(x="Passengers", y= "Months", hue="Years", data=a)  #hue semantic”, because the color of the point gains meaning:sns

# %%
sns.relplot(x="Passengers", y= "Years", data=a, kind="line")

# %%
sns.relplot(x="Months", y= "Years", data=a, kind="line")

# %%
sns.catplot(x="Passengers", y="Years", data=a)

# %%
sns.stripplot(x="Months", y="Years", data=a)   # univariate dataset

# %%
sns.boxplot(x="Passengers", y="Months", data=a)

# %%
sns.catplot(x="Months", y= "Years", data=a, kind="boxen")

# %%
sns.catplot(x="Months", y= "Years", data=a, kind="violin")

# %%
a.isnull().sum()
# Out:
# Years         0
# Months        0
# Passengers    0
# dtype: int64

# %%
a.count()
# Out:
# Years         144
# Months        144
# Passengers    144
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Years       144 non-null    int64
#  1   Months      144 non-null    object
#  2   Passengers  144 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 3.5+ KB

# %%
a.kurt()
# Out:
# Years        -1.217261
# Passengers   -0.364942
# dtype: float64

# %%
a.skew()
# Out:
# Years         0.00000
# Passengers    0.58316
# dtype: float64

# %%
a.std()
# Out:
# Years           3.464102
# Passengers    119.966317
# dtype: float64

# %%
a.var()
# Out:
# Years            12.000000
# Passengers    14391.917201
# dtype: float64
